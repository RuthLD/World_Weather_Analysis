# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 591

# %%
# Import the requests library.
import requests

# Import the API key.
from config_2 import world_weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ world_weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        #print(city_weather)
       # print(city_weather["weather"][0]['description'])
        # Parse out the needed data.
        city_lng = city_weather["coord"]["lon"]
        city_lat = city_weather["coord"]["lat"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | leningradskiy
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | kamaishi
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | saint george
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | coquimbo
# Processing Record 9 of Set 1 | nyurba
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | pisco
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | pangnirtung
# Processing Record 17 of Set 1 | camacha
# Processing Record 18 of Set 1 | kargasok
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | geraldton
# Processing Record 21 of Set 1 | chuy
# Processing Record 22 of Set 1 | visnes
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | husavik
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | guerrero negro
# Processing Record 27 of Set 1 | kielce
# Processing Record 28 of Set 1 | omboue
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | bengkulu
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | fortuna
# Processing Record 34 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 1 | alta floresta
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | hualmay
# Processing Record 38 of Set 1 | mahebourg
# Processing Record 39 of Set 1 | torbay
# Processing Record 40 of Set 1 | hoi an
# Processing Record 41 of Set 1 | komsomolskiy
# Processing Record 42 of Set 1 | saint-francois
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | santa maria
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | vestmannaeyjar
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | acarau
# Processing Record 49 of Set 1 | ponta do sol
# Processing Record 50 of Set 1 | ambilobe
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | yarmouth
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | baculin
# Processing Record 8 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 10 of Set 2 | katsuura
# Processing Record 11 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 2 | taltal
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | ishigaki
# Processing Record 15 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | brenham
# Processing Record 18 of Set 2 | saint-philippe
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | kahului
# Processing Record 21 of Set 2 | durusu
# Processing Record 22 of Set 2 | sept-iles
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | codrington
# Processing Record 27 of Set 2 | pervoye maya
# Processing Record 28 of Set 2 | nangong
# Processing Record 29 of Set 2 | vardo
# Processing Record 30 of Set 2 | imeni poliny osipenko
# Processing Record 31 of Set 2 | kudahuvadhoo
# Processing Record 32 of Set 2 | choszczno
# Processing Record 33 of Set 2 | jauharabad
# Processing Record 34 of Set 2 | fort nelson
# Processing Record 35 of Set 2 | carnarvon
# Processing Record 36 of Set 2 | blagoyevo
# Processing Record 37 of Set 2 | bristol
# Processing Record 38 of Set 2 | riyadh
# Processing Record 39 of Set 2 | karakendzha
# City not found. Skipping...
# Processing Record 40 of Set 2 | alekseyevsk
# Processing Record 41 of Set 2 | zapotiltic
# Processing Record 42 of Set 2 | pereira barreto
# Processing Record 43 of Set 2 | esperance
# Processing Record 44 of Set 2 | nemuro
# Processing Record 45 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 2 | kaitangata
# Processing Record 47 of Set 2 | bethel
# Processing Record 48 of Set 2 | hailar
# Processing Record 49 of Set 2 | cabo san lucas
# Processing Record 50 of Set 2 | kapaa
# Processing Record 1 of Set 3 | puerto escondido
# Processing Record 2 of Set 3 | itarema
# Processing Record 3 of Set 3 | caravelas
# Processing Record 4 of Set 3 | east london
# Processing Record 5 of Set 3 | fort saint james
# Processing Record 6 of Set 3 | honiara
# Processing Record 7 of Set 3 | aklavik
# Processing Record 8 of Set 3 | manuk mangkaw
# Processing Record 9 of Set 3 | saint-augustin
# Processing Record 10 of Set 3 | san patricio
# Processing Record 11 of Set 3 | sandpoint
# Processing Record 12 of Set 3 | takoradi
# Processing Record 13 of Set 3 | flinders
# Processing Record 14 of Set 3 | paita
# Processing Record 15 of Set 3 | cairns
# Processing Record 16 of Set 3 | katobu
# Processing Record 17 of Set 3 | tenamaxtlan
# Processing Record 18 of Set 3 | tessalit
# Processing Record 19 of Set 3 | kavieng
# Processing Record 20 of Set 3 | chipinge
# Processing Record 21 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | baglung
# Processing Record 24 of Set 3 | chokurdakh
# Processing Record 25 of Set 3 | pevek
# Processing Record 26 of Set 3 | tazmalt
# Processing Record 27 of Set 3 | ankpa
# Processing Record 28 of Set 3 | hasaki
# Processing Record 29 of Set 3 | avarua
# Processing Record 30 of Set 3 | nikolskoye
# Processing Record 31 of Set 3 | poronaysk
# Processing Record 32 of Set 3 | sao filipe
# Processing Record 33 of Set 3 | isangel
# Processing Record 34 of Set 3 | lebu
# Processing Record 35 of Set 3 | panama city
# Processing Record 36 of Set 3 | faanui
# Processing Record 37 of Set 3 | butaritari
# Processing Record 38 of Set 3 | antalaha
# Processing Record 39 of Set 3 | synya
# Processing Record 40 of Set 3 | dale
# Processing Record 41 of Set 3 | calabozo
# Processing Record 42 of Set 3 | ribeira grande
# Processing Record 43 of Set 3 | svetlogorsk
# Processing Record 44 of Set 3 | simao
# Processing Record 45 of Set 3 | cherskiy
# Processing Record 46 of Set 3 | thompson
# Processing Record 47 of Set 3 | machico
# Processing Record 48 of Set 3 | port antonio
# Processing Record 49 of Set 3 | hami
# Processing Record 50 of Set 3 | hobart
# Processing Record 1 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 4 | bubaque
# Processing Record 3 of Set 4 | aljezur
# Processing Record 4 of Set 4 | manokwari
# Processing Record 5 of Set 4 | matagami
# Processing Record 6 of Set 4 | nicoya
# Processing Record 7 of Set 4 | lipin bor
# Processing Record 8 of Set 4 | hearst
# Processing Record 9 of Set 4 | half moon bay
# Processing Record 10 of Set 4 | bastia
# Processing Record 11 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 4 | eydhafushi
# Processing Record 13 of Set 4 | nome
# Processing Record 14 of Set 4 | rawson
# Processing Record 15 of Set 4 | bar harbor
# Processing Record 16 of Set 4 | abaza
# Processing Record 17 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 4 | petrolina
# Processing Record 19 of Set 4 | luderitz
# Processing Record 20 of Set 4 | turbat
# Processing Record 21 of Set 4 | ayorou
# Processing Record 22 of Set 4 | te anau
# Processing Record 23 of Set 4 | torbat-e jam
# Processing Record 24 of Set 4 | williston
# Processing Record 25 of Set 4 | paciran
# Processing Record 26 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 4 | richmond
# Processing Record 28 of Set 4 | berlevag
# Processing Record 29 of Set 4 | okhotsk
# Processing Record 30 of Set 4 | mount isa
# Processing Record 31 of Set 4 | chifeng
# Processing Record 32 of Set 4 | bekhtery
# Processing Record 33 of Set 4 | narsaq
# Processing Record 34 of Set 4 | kaeo
# Processing Record 35 of Set 4 | mungwi
# Processing Record 36 of Set 4 | lagoa
# Processing Record 37 of Set 4 | meulaboh
# Processing Record 38 of Set 4 | samana
# Processing Record 39 of Set 4 | turukhansk
# Processing Record 40 of Set 4 | tebingtinggi
# Processing Record 41 of Set 4 | khromtau
# Processing Record 42 of Set 4 | xuddur
# Processing Record 43 of Set 4 | qandala
# Processing Record 44 of Set 4 | jacareacanga
# Processing Record 45 of Set 4 | grindavik
# Processing Record 46 of Set 4 | kibala
# Processing Record 47 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 4 | vieste
# Processing Record 49 of Set 4 | ixtapa
# Processing Record 50 of Set 4 | joshimath
# Processing Record 1 of Set 5 | touros
# Processing Record 2 of Set 5 | unity
# Processing Record 3 of Set 5 | copiapo
# Processing Record 4 of Set 5 | tiksi
# Processing Record 5 of Set 5 | larap
# Processing Record 6 of Set 5 | podporozhye
# Processing Record 7 of Set 5 | flin flon
# Processing Record 8 of Set 5 | ceyhan
# Processing Record 9 of Set 5 | karpogory
# Processing Record 10 of Set 5 | hovd
# Processing Record 11 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 12 of Set 5 | battipaglia
# Processing Record 13 of Set 5 | iqaluit
# Processing Record 14 of Set 5 | diu
# Processing Record 15 of Set 5 | arraial do cabo
# Processing Record 16 of Set 5 | saint anthony
# Processing Record 17 of Set 5 | celestun
# Processing Record 18 of Set 5 | cockburn town
# Processing Record 19 of Set 5 | comodoro rivadavia
# Processing Record 20 of Set 5 | klaksvik
# Processing Record 21 of Set 5 | ayacucho
# Processing Record 22 of Set 5 | srednekolymsk
# Processing Record 23 of Set 5 | lasa
# Processing Record 24 of Set 5 | estelle
# Processing Record 25 of Set 5 | longyearbyen
# Processing Record 26 of Set 5 | souillac
# Processing Record 27 of Set 5 | ketchenery
# City not found. Skipping...
# Processing Record 28 of Set 5 | buala
# Processing Record 29 of Set 5 | hofn
# Processing Record 30 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 5 | beloha
# Processing Record 32 of Set 5 | colomi
# Processing Record 33 of Set 5 | leh
# Processing Record 34 of Set 5 | sao raimundo nonato
# Processing Record 35 of Set 5 | nanortalik
# Processing Record 36 of Set 5 | tabuk
# Processing Record 37 of Set 5 | matara
# Processing Record 38 of Set 5 | clyde river
# Processing Record 39 of Set 5 | pinsk
# Processing Record 40 of Set 5 | salalah
# Processing Record 41 of Set 5 | meadow lake
# Processing Record 42 of Set 5 | praia
# Processing Record 43 of Set 5 | boshan
# Processing Record 44 of Set 5 | manono
# Processing Record 45 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 5 | ternate
# Processing Record 47 of Set 5 | san cristobal
# Processing Record 48 of Set 5 | ossora
# Processing Record 49 of Set 5 | saskylakh
# Processing Record 50 of Set 5 | galle
# Processing Record 1 of Set 6 | daru
# Processing Record 2 of Set 6 | ornskoldsvik
# Processing Record 3 of Set 6 | bunga
# Processing Record 4 of Set 6 | patratu
# City not found. Skipping...
# Processing Record 5 of Set 6 | lavrentiya
# Processing Record 6 of Set 6 | namatanai
# Processing Record 7 of Set 6 | bara
# Processing Record 8 of Set 6 | maceio
# Processing Record 9 of Set 6 | genhe
# Processing Record 10 of Set 6 | maniitsoq
# Processing Record 11 of Set 6 | laguna
# Processing Record 12 of Set 6 | lagos
# Processing Record 13 of Set 6 | lompoc
# Processing Record 14 of Set 6 | kavaratti
# Processing Record 15 of Set 6 | deputatskiy
# Processing Record 16 of Set 6 | pemangkat
# Processing Record 17 of Set 6 | charters towers
# Processing Record 18 of Set 6 | sorong
# Processing Record 19 of Set 6 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 20 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 6 | ostersund
# Processing Record 22 of Set 6 | sazava
# Processing Record 23 of Set 6 | zhigansk
# Processing Record 24 of Set 6 | saurimo
# Processing Record 25 of Set 6 | gunnedah
# Processing Record 26 of Set 6 | luganville
# Processing Record 27 of Set 6 | sao francisco do sul
# Processing Record 28 of Set 6 | southbridge
# Processing Record 29 of Set 6 | broken hill
# Processing Record 30 of Set 6 | vangaindrano
# Processing Record 31 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 6 | ridgecrest
# Processing Record 33 of Set 6 | smithers
# Processing Record 34 of Set 6 | dingle
# Processing Record 35 of Set 6 | horsham
# Processing Record 36 of Set 6 | egvekinot
# Processing Record 37 of Set 6 | ust-koksa
# Processing Record 38 of Set 6 | bathsheba
# Processing Record 39 of Set 6 | mbandaka
# Processing Record 40 of Set 6 | muros
# Processing Record 41 of Set 6 | cabatuan
# Processing Record 42 of Set 6 | acapulco
# Processing Record 43 of Set 6 | yarada
# Processing Record 44 of Set 6 | saint pete beach
# Processing Record 45 of Set 6 | catamarca
# Processing Record 46 of Set 6 | jutai
# Processing Record 47 of Set 6 | oktyabrskiy
# Processing Record 48 of Set 6 | kiunga
# Processing Record 49 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 6 | mbaiki
# Processing Record 1 of Set 7 | agadir
# Processing Record 2 of Set 7 | najran
# Processing Record 3 of Set 7 | tabou
# Processing Record 4 of Set 7 | kutum
# Processing Record 5 of Set 7 | erzin
# Processing Record 6 of Set 7 | iisalmi
# Processing Record 7 of Set 7 | palmdale
# Processing Record 8 of Set 7 | aswan
# Processing Record 9 of Set 7 | dedza
# Processing Record 10 of Set 7 | eregli
# Processing Record 11 of Set 7 | cidreira
# Processing Record 12 of Set 7 | batagay
# Processing Record 13 of Set 7 | rio grande
# Processing Record 14 of Set 7 | baiao
# Processing Record 15 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 7 | ancud
# Processing Record 17 of Set 7 | kadaya
# Processing Record 18 of Set 7 | dobroye
# Processing Record 19 of Set 7 | sokolo
# Processing Record 20 of Set 7 | archidona
# Processing Record 21 of Set 7 | northam
# Processing Record 22 of Set 7 | nizwa
# Processing Record 23 of Set 7 | fare
# Processing Record 24 of Set 7 | tyret pervaya
# Processing Record 25 of Set 7 | moron
# Processing Record 26 of Set 7 | sioux lookout
# Processing Record 27 of Set 7 | inuvik
# Processing Record 28 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 7 | oskemen
# Processing Record 30 of Set 7 | yulara
# Processing Record 31 of Set 7 | gushi
# Processing Record 32 of Set 7 | coihaique
# Processing Record 33 of Set 7 | zyryanka
# Processing Record 34 of Set 7 | talnakh
# Processing Record 35 of Set 7 | milingimbi
# City not found. Skipping...
# Processing Record 36 of Set 7 | khani
# Processing Record 37 of Set 7 | ismailia
# Processing Record 38 of Set 7 | yokadouma
# Processing Record 39 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 40 of Set 7 | catuday
# Processing Record 41 of Set 7 | mount gambier
# Processing Record 42 of Set 7 | huaicheng
# Processing Record 43 of Set 7 | pochutla
# Processing Record 44 of Set 7 | kita
# Processing Record 45 of Set 7 | ostrovnoy
# Processing Record 46 of Set 7 | utiel
# Processing Record 47 of Set 7 | pouembout
# Processing Record 48 of Set 7 | fairbanks
# Processing Record 49 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 50 of Set 7 | padang
# Processing Record 1 of Set 8 | broome
# Processing Record 2 of Set 8 | vila franca do campo
# Processing Record 3 of Set 8 | slave lake
# Processing Record 4 of Set 8 | jijiga
# Processing Record 5 of Set 8 | buluang
# Processing Record 6 of Set 8 | ulladulla
# Processing Record 7 of Set 8 | los llanos de aridane
# Processing Record 8 of Set 8 | buin
# Processing Record 9 of Set 8 | camalu
# Processing Record 10 of Set 8 | ahipara
# Processing Record 11 of Set 8 | sulangan
# Processing Record 12 of Set 8 | papayal
# Processing Record 13 of Set 8 | bacolod
# Processing Record 14 of Set 8 | mayo
# Processing Record 15 of Set 8 | robertsport
# Processing Record 16 of Set 8 | camabatela
# Processing Record 17 of Set 8 | juneau
# Processing Record 18 of Set 8 | great bend
# Processing Record 19 of Set 8 | iskateley
# Processing Record 20 of Set 8 | portland
# Processing Record 21 of Set 8 | itapuranga
# Processing Record 22 of Set 8 | male
# Processing Record 23 of Set 8 | holme
# Processing Record 24 of Set 8 | varadero
# Processing Record 25 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 26 of Set 8 | diamantino
# Processing Record 27 of Set 8 | ullapool
# Processing Record 28 of Set 8 | ratnagiri
# Processing Record 29 of Set 8 | havelock
# Processing Record 30 of Set 8 | gat
# Processing Record 31 of Set 8 | homer
# Processing Record 32 of Set 8 | gari
# Processing Record 33 of Set 8 | raudeberg
# Processing Record 34 of Set 8 | kununurra
# Processing Record 35 of Set 8 | oroville
# Processing Record 36 of Set 8 | birobidzhan
# Processing Record 37 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 38 of Set 8 | kirkwall
# Processing Record 39 of Set 8 | port-cartier
# Processing Record 40 of Set 8 | masalli
# Processing Record 41 of Set 8 | upernavik
# Processing Record 42 of Set 8 | kedrovyy
# Processing Record 43 of Set 8 | azul
# Processing Record 44 of Set 8 | mumford
# Processing Record 45 of Set 8 | sinnamary
# Processing Record 46 of Set 8 | rioblanco
# Processing Record 47 of Set 8 | sur
# Processing Record 48 of Set 8 | lincoln
# Processing Record 49 of Set 8 | kuybysheve
# Processing Record 50 of Set 8 | shebunino
# Processing Record 1 of Set 9 | wawa
# Processing Record 2 of Set 9 | hermiston
# Processing Record 3 of Set 9 | bereda
# Processing Record 4 of Set 9 | nuuk
# Processing Record 5 of Set 9 | lingao
# Processing Record 6 of Set 9 | vila velha
# Processing Record 7 of Set 9 | tiznit
# Processing Record 8 of Set 9 | talara
# Processing Record 9 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 9 | belyy yar
# Processing Record 11 of Set 9 | korla
# Processing Record 12 of Set 9 | bouza
# Processing Record 13 of Set 9 | lhuntshi
# City not found. Skipping...
# Processing Record 14 of Set 9 | bonnyville
# Processing Record 15 of Set 9 | ayan
# Processing Record 16 of Set 9 | las margaritas
# Processing Record 17 of Set 9 | inyonga
# Processing Record 18 of Set 9 | provideniya
# Processing Record 19 of Set 9 | severo-yeniseyskiy
# Processing Record 20 of Set 9 | port stanley
# Processing Record 21 of Set 9 | menongue
# Processing Record 22 of Set 9 | champerico
# Processing Record 23 of Set 9 | yuzhnyy
# Processing Record 24 of Set 9 | miri
# Processing Record 25 of Set 9 | barcarena
# Processing Record 26 of Set 9 | saldanha
# Processing Record 27 of Set 9 | narrabri
# Processing Record 28 of Set 9 | obregon
# Processing Record 29 of Set 9 | burghausen
# Processing Record 30 of Set 9 | verkhnevilyuysk
# Processing Record 31 of Set 9 | kangavar
# Processing Record 32 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 33 of Set 9 | krasnokamensk
# Processing Record 34 of Set 9 | aquiraz
# Processing Record 35 of Set 9 | georgiyevka
# Processing Record 36 of Set 9 | bac lieu
# Processing Record 37 of Set 9 | tuatapere
# Processing Record 38 of Set 9 | severo-kurilsk
# Processing Record 39 of Set 9 | nsanje
# Processing Record 40 of Set 9 | requena
# Processing Record 41 of Set 9 | tome-acu
# City not found. Skipping...
# Processing Record 42 of Set 9 | sovetskiy
# Processing Record 43 of Set 9 | lieksa
# Processing Record 44 of Set 9 | yar-sale
# Processing Record 45 of Set 9 | agva
# City not found. Skipping...
# Processing Record 46 of Set 9 | santa fe
# Processing Record 47 of Set 9 | port blair
# Processing Record 48 of Set 9 | general cepeda
# Processing Record 49 of Set 9 | bayir
# Processing Record 50 of Set 9 | burriana
# Processing Record 1 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 10 | boueni
# Processing Record 3 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 10 | san policarpo
# Processing Record 5 of Set 10 | esna
# Processing Record 6 of Set 10 | angra
# City not found. Skipping...
# Processing Record 7 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 8 of Set 10 | atambua
# Processing Record 9 of Set 10 | ilulissat
# Processing Record 10 of Set 10 | yelizovo
# Processing Record 11 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 10 | ankazoabo
# Processing Record 13 of Set 10 | udachnyy
# Processing Record 14 of Set 10 | taseyevo
# Processing Record 15 of Set 10 | blythe
# Processing Record 16 of Set 10 | shingu
# Processing Record 17 of Set 10 | ust-kuyga
# Processing Record 18 of Set 10 | bauchi
# Processing Record 19 of Set 10 | groa
# Processing Record 20 of Set 10 | honningsvag
# Processing Record 21 of Set 10 | werda
# Processing Record 22 of Set 10 | pogranichnyy
# Processing Record 23 of Set 10 | pinheiro machado
# Processing Record 24 of Set 10 | bluefield
# Processing Record 25 of Set 10 | kampot
# Processing Record 26 of Set 10 | castanos
# Processing Record 27 of Set 10 | kushiro
# Processing Record 28 of Set 10 | lyskovo
# Processing Record 29 of Set 10 | sabha
# Processing Record 30 of Set 10 | zabaykalsk
# Processing Record 31 of Set 10 | svetlaya
# Processing Record 32 of Set 10 | mehamn
# Processing Record 33 of Set 10 | mirandopolis
# Processing Record 34 of Set 10 | virginia beach
# Processing Record 35 of Set 10 | baykit
# Processing Record 36 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 10 | mezen
# Processing Record 38 of Set 10 | da nang
# Processing Record 39 of Set 10 | lofthus
# Processing Record 40 of Set 10 | parakou
# Processing Record 41 of Set 10 | susehri
# Processing Record 42 of Set 10 | haines junction
# Processing Record 43 of Set 10 | zharkent
# Processing Record 44 of Set 10 | wuan
# Processing Record 45 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 10 | xining
# Processing Record 47 of Set 10 | jaszszentlaszlo
# Processing Record 48 of Set 10 | gushikawa
# Processing Record 49 of Set 10 | torrington
# Processing Record 50 of Set 10 | san quintin
# Processing Record 1 of Set 11 | tawang
# Processing Record 2 of Set 11 | victoria
# Processing Record 3 of Set 11 | rockport
# Processing Record 4 of Set 11 | singarayakonda
# Processing Record 5 of Set 11 | corinto
# Processing Record 6 of Set 11 | belmonte
# Processing Record 7 of Set 11 | grand-santi
# Processing Record 8 of Set 11 | nishihara
# Processing Record 9 of Set 11 | palana
# Processing Record 10 of Set 11 | constitucion
# Processing Record 11 of Set 11 | miedzyrzec podlaski
# Processing Record 12 of Set 11 | piacabucu
# Processing Record 13 of Set 11 | san pedro
# Processing Record 14 of Set 11 | norman wells
# Processing Record 15 of Set 11 | sibolga
# Processing Record 16 of Set 11 | zhezkazgan
# Processing Record 17 of Set 11 | utevka
# Processing Record 18 of Set 11 | eureka
# Processing Record 19 of Set 11 | namibe
# Processing Record 20 of Set 11 | berdigestyakh
# Processing Record 21 of Set 11 | regina
# Processing Record 22 of Set 11 | boguchany
# Processing Record 23 of Set 11 | nambucca heads
# Processing Record 24 of Set 11 | ahuimanu
# Processing Record 25 of Set 11 | vao
# Processing Record 26 of Set 11 | alice springs
# Processing Record 27 of Set 11 | maumere
# Processing Record 28 of Set 11 | camopi
# Processing Record 29 of Set 11 | ugoofaaru
# Processing Record 30 of Set 11 | beidao
# Processing Record 31 of Set 11 | mahibadhoo
# Processing Record 32 of Set 11 | wangaratta
# Processing Record 33 of Set 11 | brae
# Processing Record 34 of Set 11 | jabinyanah
# Processing Record 35 of Set 11 | ponta delgada
# Processing Record 36 of Set 11 | palu
# Processing Record 37 of Set 11 | stara vyzhivka
# Processing Record 38 of Set 11 | kurilsk
# Processing Record 39 of Set 11 | cap malheureux
# Processing Record 40 of Set 11 | hinton
# Processing Record 41 of Set 11 | kigoma
# Processing Record 42 of Set 11 | dunedin
# Processing Record 43 of Set 11 | ingham
# Processing Record 44 of Set 11 | kazanskoye
# Processing Record 45 of Set 11 | salcininkai
# Processing Record 46 of Set 11 | chumikan
# Processing Record 47 of Set 11 | sharan
# Processing Record 48 of Set 11 | shikarpur
# Processing Record 49 of Set 11 | bousso
# Processing Record 50 of Set 11 | malpe
# Processing Record 1 of Set 12 | amahai
# Processing Record 2 of Set 12 | bandarbeyla
# Processing Record 3 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 4 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 12 | suntar
# Processing Record 6 of Set 12 | yambio
# Processing Record 7 of Set 12 | san matias
# Processing Record 8 of Set 12 | aqtobe
# Processing Record 9 of Set 12 | stephenville
# Processing Record 10 of Set 12 | umtata
# Processing Record 11 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 13 of Set 12 | yumbe
# Processing Record 14 of Set 12 | evensk
# Processing Record 15 of Set 12 | kruisfontein
# Processing Record 16 of Set 12 | manicore
# Processing Record 17 of Set 12 | eyl
# Processing Record 18 of Set 12 | goba
# Processing Record 19 of Set 12 | grenville
# Processing Record 20 of Set 12 | lemesos
# City not found. Skipping...
# Processing Record 21 of Set 12 | naze
# Processing Record 22 of Set 12 | guatire
# Processing Record 23 of Set 12 | sobolevo
# Processing Record 24 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 25 of Set 12 | kirishi
# Processing Record 26 of Set 12 | kota kinabalu
# Processing Record 27 of Set 12 | otane
# Processing Record 28 of Set 12 | dukat
# Processing Record 29 of Set 12 | pacifica
# Processing Record 30 of Set 12 | morehead
# Processing Record 31 of Set 12 | esterhazy
# Processing Record 32 of Set 12 | sabang
# Processing Record 33 of Set 12 | santiago
# Processing Record 34 of Set 12 | annau
# Processing Record 35 of Set 12 | hyeres
# Processing Record 36 of Set 12 | sangar
# Processing Record 37 of Set 12 | grand gaube
# Processing Record 38 of Set 12 | kidal
# Processing Record 39 of Set 12 | lucapa
# Processing Record 40 of Set 12 | klyuchi
# Processing Record 41 of Set 12 | labuhan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check that over 500 cities are in city_data
print(len(city_data))
# Out:
# 545

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Leningradskiy      RU  69.3833  178.4167    -12.03        97         100
# 1          Vaini      TO -21.2000 -175.2000     73.40       100          75
# 2       Kamaishi      JP  39.2667  141.8833     45.86        84         100
# 3       Tasiilaq      GL  65.6145  -37.6368     33.80        75          75
# 4    Yellowknife      CA  62.4560 -114.3525     -2.00        59          40
# 5   Saint George      US  37.1041 -113.5841     57.00        43           1
# 6         Barrow      US  71.2906 -156.7887    -14.80        76          40
# 7       Coquimbo      CL -29.9533  -71.3436     68.00        64          20
# 8         Nyurba      RU  63.2842  118.3319    -23.46        96          63
# 9   Punta Arenas      CL -53.1500  -70.9167     59.00        51          75
#
#    Wind Speed Current Description                 Date
# 0        8.90     overcast clouds  2021-03-21 18:16:09
# 1       10.36       moderate rain  2021-03-21 18:16:09
# 2        5.66     overcast clouds  2021-03-21 18:16:10
# 3        9.22       broken clouds  2021-03-21 18:16:10
# 4       12.66                snow  2021-03-21 18:16:10
# 5        4.61           clear sky  2021-03-21 18:16:11
# 6       10.36    scattered clouds  2021-03-21 18:15:54
# 7       17.27          few clouds  2021-03-21 18:11:59
# 8        6.46       broken clouds  2021-03-21 18:16:11
# 9       19.57       broken clouds  2021-03-21 18:13:59

# %%
# Reorder the columns of the city data df.
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Leningradskiy      RU  69.3833  178.4167    -12.03        97         100
# 1          Vaini      TO -21.2000 -175.2000     73.40       100          75
# 2       Kamaishi      JP  39.2667  141.8833     45.86        84         100
# 3       Tasiilaq      GL  65.6145  -37.6368     33.80        75          75
# 4    Yellowknife      CA  62.4560 -114.3525     -2.00        59          40
# 5   Saint George      US  37.1041 -113.5841     57.00        43           1
# 6         Barrow      US  71.2906 -156.7887    -14.80        76          40
# 7       Coquimbo      CL -29.9533  -71.3436     68.00        64          20
# 8         Nyurba      RU  63.2842  118.3319    -23.46        96          63
# 9   Punta Arenas      CL -53.1500  -70.9167     59.00        51          75
#
#    Wind Speed Current Description
# 0        8.90     overcast clouds
# 1       10.36       moderate rain
# 2        5.66     overcast clouds
# 3        9.22       broken clouds
# 4       12.66                snow
# 5        4.61           clear sky
# 6       10.36    scattered clouds
# 7       17.27          few clouds
# 8        6.46       broken clouds
# 9       19.57       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
